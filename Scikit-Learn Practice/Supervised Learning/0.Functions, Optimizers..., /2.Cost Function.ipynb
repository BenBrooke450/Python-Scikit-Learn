# %% [markdown]
# ![image.png](attachment:b323efa3-1337-4a14-a905-a1c6d785fe19.png)

# %% [markdown]
# ![image.png](attachment:75e05c38-9061-43d4-ab42-661dfb49ea03.png)

# %% [markdown]
# ![image.png](attachment:0cd8de81-7961-44cc-b0cf-9a9c1588487d.png)
